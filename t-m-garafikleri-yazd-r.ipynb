# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/ANNOTATORS
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/SHA256SUMS.txt
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/RECORDS
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/README
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/biometric.shtml
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_07/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_07/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_07/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_07/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_07/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_07/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_40/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_38/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_38/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_38/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_38/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_38/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_38/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_30/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_39/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_39/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_39/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_39/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_39/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_39/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_10/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_87/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_87/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_87/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_87/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_87/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_87/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_58/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_58/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_58/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_58/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_58/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_58/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_85/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_79/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_79/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_79/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_79/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_79/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_79/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_84/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_84/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_84/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_84/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_84/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_84/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_22/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_22/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_22/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_22/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_22/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_22/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_48/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_48/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_48/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_48/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_48/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_48/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_41/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_41/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_41/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_41/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_41/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_41/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_23/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_23/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_23/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_23/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_23/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_23/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_75/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_35/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_25/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_31/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_31/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_31/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_31/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_31/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_31/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_20/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_20/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_20/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_20/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_20/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_20/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_76/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_60/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_68/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_68/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_68/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_68/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_68/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_68/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_61/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_82/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_82/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_82/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_82/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_82/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_82/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_50/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_50/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_50/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_50/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_50/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_50/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_47/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_47/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_47/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_47/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_47/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_47/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_89/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_89/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_89/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_89/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_89/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_89/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_16/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_67/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_65/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_65/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_65/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_65/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_65/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_65/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_56/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_56/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_56/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_56/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_56/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_56/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_12/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_12/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_12/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_12/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_12/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_12/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_59/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_51/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_71/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_6.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_7.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_7.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_6.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_6.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_09/rec_7.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/biometric.shtml
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/arrow_hor.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/index_wide_screen.shtml
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/ecg_noise_net.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/noise_filter_2.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/wavelet_drift_correction.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/ecg_noise_both.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/pqrst_set_rate_corrected.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/arrow_ver.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/noise_filter_1.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/hor_arrow.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/wavelet_drift_correction_noisy.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/ecg.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/pqrst_set_1.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/ecg_noise_drift.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/ecg_noise_high.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/pqrst_set_2.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/pqrst_set_atypical.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/ecg_db_record.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/pqrst_set_rate_original.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/pqrst_set_vertical_correction.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/.old/images/index.shtml
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_37/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_37/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_37/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_37/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_37/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_37/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_78/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_78/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_78/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_78/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_78/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_78/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_77/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/class_metrics_reduced.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/system_classification.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/oper_Wavelet_Drift_Correction.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_biometric_over_day.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/arrow_hor.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/index_wide_screen.shtml
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_noise_net.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/noise_filter_2.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_noise_both_opers.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_biometric_configurations.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/wavelet_drift_correction.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_noise_both.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/pqrst_set_rate_corrected.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/arrow_ver.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/class_metrics_initial.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/noise_filter_1.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/hor_arrow.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/system_initial_feature_space.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_noise_net_opers.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/wavelet_drift_correction_noisy.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_biometric_over_time.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/pqrst_set_1.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_noise_drift.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/oper_Smoothing.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/feature_space_2D.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_noise_high.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/pqrst_set_2.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/system_preprocessing.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_noise_high_opers.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/oper_Lowpass_Filter.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/pqrst_set_atypical.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_db_record.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/system_synthesis.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/system_feature_space_reduction.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/pqrst_set_rate_original.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_biometric_over_time_.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/pqrst_config.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_noise_drift_opers.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/pqrst_set_vertical_correction.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/index.shtml
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/oper_Adaptive_Bandstop_Filter.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/images/ecg_biometric_heart_rate.png
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_27/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_29/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_29/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_29/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_29/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_29/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_29/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_18/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_18/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_18/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_18/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_18/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_18/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_03/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_03/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_03/rec_1.dat
# ...
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_7.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_6.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_10.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_11.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_9.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_11.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_6.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_10.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_8.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_9.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_9.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_8.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_7.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_52/rec_8.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_14/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_44/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_44/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_44/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_44/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_44/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_44/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_17/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_17/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_17/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_17/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_17/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_17/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_73/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_73/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_73/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_73/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_73/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_73/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_19/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_19/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_19/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_19/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_19/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_19/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_26/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_53/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_34/rec_4.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_55/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_55/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_55/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_55/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_55/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_55/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_33/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_33/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_33/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_33/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_33/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_33/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_57/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_86/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_86/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_86/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_86/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_86/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_86/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_04/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_04/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_04/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_04/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_04/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_04/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_3.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_1.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_1.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_4.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_2.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_2.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_4.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_3.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_2.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_5.dat
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_5.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_5.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_1.atr
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_3.hea
# /kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_24/rec_4.dat

# %%
"""
=============================================================
  ECG-ID DATABASE — EKG SİNYAL ANALİZİ
  Veri Seti: ecg-id-database-1.0.0 (PhysioNet)

  İçerik:
    1. WFDB Formatında Veri Okuma (.dat / .hea)
    2. Baseline Correction  (High-pass Butterworth filtre)
    3. R Dalgası Tespiti    (scipy.signal.find_peaks)
    4. FFT Analizi          (np.fft.rfft)
    5. Tüm Grafikler
    6. Özet İstatistikler

  Kullanım:
    - DATA_DIR değişkenini kendi zip/klasör yoluna göre ayarla
    - PERSON ve RECORD değişkenleriyle hangi kaydı inceleyeceğini seç
=============================================================
"""

import os
import struct
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy.signal import butter, filtfilt, find_peaks

# ─────────────────────────────────────────────────────────
# ⚙️  AYARLAR — Buradan değiştirebilirsin
# ─────────────────────────────────────────────────────────
DATA_DIR = "/kaggle/input/datasets/emirhanipek/veriler/ecg-id-database-1.0.0/ecg-id-database-1.0.0"
PERSON   = "Person_07"
RECORD   = "rec_1"
# 1. WFDB OKUYUCU (wfdb kütüphanesi olmadan .dat/.hea okur)
# ─────────────────────────────────────────────────────────
def read_wfdb(data_dir, person, record):
    """
    .hea başlığını ayrıştırır, .dat dosyasını okur.
    Dönüş:
        signals : (n_samples, n_channels) numpy array — mV cinsinden
        fs      : Örnekleme frekansı (Hz)
        info    : Sözlük (yaş, cinsiyet, tarih)
        ch_names: Kanal isimleri listesi
    """
    base   = os.path.join(data_dir, person, record)
    hea_path = base + ".hea"
    dat_path = base + ".dat"

    # Başlık satırlarını oku
    with open(hea_path, "r") as f:
        lines = f.readlines()

    # İlk satır: kayıt adı, kanal sayısı, fs, örnek sayısı
    header  = lines[0].split()
    n_ch    = int(header[1])
    fs      = int(header[2])
    n_samp  = int(header[3])

    # Sinyal satırları
    gains, baselines, ch_names = [], [], []
    for i in range(1, 1 + n_ch):
        parts = lines[i].split()
        gains.append(float(parts[2]))       # ADC gain (LSB/mV)
        baselines.append(float(parts[4]))   # ADC baseline
        ch_names.append(" ".join(parts[8:]) if len(parts) > 8 else f"CH{i}")

    # Yorum satırlarından meta veri
    info = {}
    for line in lines:
        if line.startswith("# Age"):
            info["Yaş"]     = line.split(":")[1].strip()
        elif line.startswith("# Sex"):
            info["Cinsiyet"]= line.split(":")[1].strip()
        elif line.startswith("# ECG date"):
            info["Tarih"]   = line.split(":")[1].strip()

    # İkili veri: format 16 → signed int16, kanallar aralarında sıralı
    raw = np.fromfile(dat_path, dtype=np.int16)
    raw = raw.reshape(-1, n_ch)            # (n_samples, n_channels)

    # mV'a dönüştür
    signals = np.zeros_like(raw, dtype=float)
    for c in range(n_ch):
        signals[:, c] = (raw[:, c] - baselines[c]) / gains[c]

    return signals, fs, info, ch_names


# ─────────────────────────────────────────────────────────
# 2. BASELINE CORRECTION
# ─────────────────────────────────────────────────────────
def baseline_correction(signal, fs, cutoff=0.5, order=4):
    """
    Yüksek geçirgen Butterworth filtresi.
    cutoff=0.5 Hz → solunum/hareket kaynaklı drift giderilir.
    filtfilt → sıfır faz kayması (ileri + geri filtreleme).
    """
    nyq = fs / 2
    b, a = butter(order, cutoff / nyq, btype='high', analog=False)
    return filtfilt(b, a, signal)


# ─────────────────────────────────────────────────────────
# 3. FFT ANALİZİ
# ─────────────────────────────────────────────────────────
def compute_fft(signal, fs):
    """
    Tek taraflı normalize genlik spektrumu.
    Dönüş: freqs (Hz), magnitude
    """
    N   = len(signal)
    fft = np.fft.rfft(signal)
    mag = np.abs(fft) * 2 / N
    frq = np.fft.rfftfreq(N, d=1/fs)
    return frq, mag


# ─────────────────────────────────────────────────────────
# 4. VERİYİ OKU
# ─────────────────────────────────────────────────────────
print(f"Kayıt okunuyor: {PERSON}/{RECORD}")
signals, fs, info, ch_names = read_wfdb(DATA_DIR, PERSON, RECORD)

print(f"  Örnekleme Frekansı : {fs} Hz")
print(f"  Kanal Sayısı       : {signals.shape[1]}")
print(f"  Toplam Örnek       : {signals.shape[0]} ({signals.shape[0]/fs:.1f} sn)")
for k, v in info.items():
    print(f"  {k:<12}: {v}")

# Ham EKG — Kanal 0 (ECG I — ham)
raw_ecg = signals[:, 0]

# ─────────────────────────────────────────────────────────
# 5. BASELINE CORRECTION UYGULA
# ─────────────────────────────────────────────────────────
corrected_ecg = baseline_correction(raw_ecg, fs, cutoff=0.5)

# ─────────────────────────────────────────────────────────
# 6. R DALGASI TESPİTİ
# ─────────────────────────────────────────────────────────
# Yükseklik eşiği: corrected sinyalin maksimumunun %50'si
threshold = 0.5 * np.max(corrected_ecg)
r_raw, _  = find_peaks(raw_ecg,       height=threshold, distance=fs//3)
r_cor, _  = find_peaks(corrected_ecg, height=threshold, distance=fs//3)

# ─────────────────────────────────────────────────────────
# 7. FFT
# ─────────────────────────────────────────────────────────
freqs_raw, mag_raw = compute_fft(raw_ecg,       fs)
freqs_cor, mag_cor = compute_fft(corrected_ecg, fs)

# ─────────────────────────────────────────────────────────
# 8. TÜM KAYITLAR İÇİN GRAFİK + İSTATİSTİK
# ─────────────────────────────────────────────────────────

rec_dir = os.path.join(DATA_DIR, PERSON)
records = sorted(set(f.replace('.dat','') for f in os.listdir(rec_dir) if f.endswith('.dat')))

print(f"\n{PERSON} için {len(records)} kayıt bulundu: {records}\n")

for rec in records:
    print(f"{'='*55}")
    print(f"  İşleniyor: {PERSON} / {rec}")
    print(f"{'='*55}")

    # Veriyi oku
    sigs, fs_, info_, chs = read_wfdb(DATA_DIR, PERSON, rec)
    ecg = sigs[:, 0]

    # Baseline correction
    cor = baseline_correction(ecg, fs_)

    # R dalgası tespiti
    threshold = 0.5 * np.max(cor)
    r_raw_, _ = find_peaks(ecg, height=threshold, distance=fs_//3)
    r_cor_, _ = find_peaks(cor, height=threshold, distance=fs_//3)

    # FFT
    freqs_r, mag_r = compute_fft(ecg, fs_)
    freqs_c, mag_c = compute_fft(cor,  fs_)

    # Zaman ekseni
    t_ = np.arange(len(ecg)) / fs_
    n3s = int(3 * fs_)

    # ── Grafik ──────────────────────────────────────────
    fig = plt.figure(figsize=(16, 22))
    fig.suptitle(
        f"ECG-ID Database — {PERSON} / {rec}\n"
        f"Yaş: {info_.get('Yaş','?')}  |  "
        f"Cinsiyet: {info_.get('Cinsiyet','?')}  |  "
        f"Tarih: {info_.get('Tarih','?')}  |  "
        f"fs={fs_} Hz",
        fontsize=13, fontweight='bold', y=0.99
    )
    gs = gridspec.GridSpec(5, 1, figure=fig, hspace=0.45)

    # Plot 1: Ham EKG
    ax1 = fig.add_subplot(gs[0])
    ax1.plot(t_, ecg, color='steelblue', lw=0.7, label='Ham EKG (Kanal 0)')
    ax1.plot(r_raw_/fs_, ecg[r_raw_], 'rx', ms=8, mew=2, label=f'R Dalgası (n={len(r_raw_)})')
    ax1.set_title("Ham EKG — Tüm Kayıt + R Dalgası Tespiti", fontsize=11)
    ax1.set_xlabel("Zaman (s)")
    ax1.set_ylabel("Genlik (mV)")
    ax1.legend(fontsize=8)
    ax1.grid(True, alpha=0.3)

    # Plot 2: Baseline Corrected EKG
    ax2 = fig.add_subplot(gs[1])
    ax2.plot(t_, cor, color='darkorange', lw=0.7, label='Baseline Corrected EKG')
    ax2.plot(r_cor_/fs_, cor[r_cor_], 'rx', ms=8, mew=2, label=f'R Dalgası (n={len(r_cor_)})')
    ax2.axhline(0, color='gray', ls='--', lw=0.6, label='Sıfır çizgisi')
    ax2.set_title("Baseline Correction Sonrası EKG (High-pass, 0.5 Hz)", fontsize=11)
    ax2.set_xlabel("Zaman (s)")
    ax2.set_ylabel("Genlik (mV)")
    ax2.legend(fontsize=8)
    ax2.grid(True, alpha=0.3)

    # Plot 3: Ham vs Corrected (ilk 3 sn)
    ax3 = fig.add_subplot(gs[2])
    ax3.plot(t_[:n3s], ecg[:n3s], color='steelblue',  lw=1.0, alpha=0.8, label='Ham EKG')
    ax3.plot(t_[:n3s], cor[:n3s], color='darkorange', lw=1.0, alpha=0.8, label='Corrected EKG')
    ax3.set_title("Ham vs Baseline Corrected EKG — İlk 3 Saniye", fontsize=11)
    ax3.set_xlabel("Zaman (s)")
    ax3.set_ylabel("Genlik (mV)")
    ax3.legend(fontsize=8)
    ax3.grid(True, alpha=0.3)

    # Plot 4: FFT Ham
    ax4 = fig.add_subplot(gs[3])
    ax4.plot(freqs_r, mag_r, color='steelblue', lw=0.8)
    ax4.axvspan(0,   0.5, alpha=0.18, color='red',    label='Baseline Wander (<0.5 Hz)')
    ax4.axvspan(0.5, 2.5, alpha=0.18, color='green',  label='P & T Dalgaları (0.5–2.5 Hz)')
    ax4.axvspan(5,   40,  alpha=0.18, color='orange', label='QRS Kompleksi (5–40 Hz)')
    ax4.axvspan(40,  100, alpha=0.12, color='gray',   label='Yüksek frekans / Gürültü (>40 Hz)')
    ax4.set_title("FFT — Ham EKG Frekans Spektrumu", fontsize=11)
    ax4.set_xlabel("Frekans (Hz)")
    ax4.set_ylabel("Genlik")
    ax4.set_xlim(0, 100)
    ax4.legend(fontsize=7, loc='upper right')
    ax4.grid(True, alpha=0.3)

    # Plot 5: FFT Corrected
    ax5 = fig.add_subplot(gs[4])
    ax5.plot(freqs_c, mag_c, color='darkorange', lw=0.8)
    ax5.axvspan(0,   0.5, alpha=0.18, color='red',    label='Baseline Wander temizlendi')
    ax5.axvspan(0.5, 2.5, alpha=0.18, color='green',  label='P & T Dalgaları (0.5–2.5 Hz)')
    ax5.axvspan(5,   40,  alpha=0.18, color='orange', label='QRS Kompleksi (5–40 Hz)')
    ax5.axvspan(40,  100, alpha=0.12, color='gray',   label='Yüksek frekans / Gürültü (>40 Hz)')
    ax5.set_title("FFT — Baseline Correction Sonrası EKG Frekans Spektrumu", fontsize=11)
    ax5.set_xlabel("Frekans (Hz)")
    ax5.set_ylabel("Genlik")
    ax5.set_xlim(0, 100)
    ax5.legend(fontsize=7, loc='upper right')
    ax5.grid(True, alpha=0.3)

    # Kaydet ve göster
    out_path = f"/kaggle/working/{PERSON}_{rec}_analiz.png"
    plt.savefig(out_path, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"  Grafik kaydedildi: {out_path}")

    # İstatistikler
    print(f"  Süre           : {len(ecg)/fs_:.1f} saniye")
    print(f"  R Dalgası (ham): {len(r_raw_)}")
    print(f"  R Dalgası (cor): {len(r_cor_)}")
    if len(r_cor_) > 1:
        rr_ms = np.diff(r_cor_) / fs_ * 1000
        bpm   = 60 / (np.mean(rr_ms) / 1000)
        print(f"  Kalp Hızı      : {bpm:.1f} BPM")
        print(f"  Ort. RR Aralığı: {np.mean(rr_ms):.1f} ms")
        print(f"  RR Std (HRV)   : {np.std(rr_ms):.1f} ms")
    print()

# ─────────────────────────────────────────────────────────
# 10. BAŞKA KAYITLARI ANALİZ ETMEK İÇİN DÖNGÜ
# ─────────────────────────────────────────────────────────
# Aşağıdaki bloğu etkinleştirirsen Person_01'in tüm kayıtlarını analiz eder:
ANALYZE_ALL = True
if ANALYZE_ALL:
    rec_dir = os.path.join(DATA_DIR, PERSON)
    records = sorted(set(f.replace('.dat','') for f in os.listdir(rec_dir) if f.endswith('.dat')))
    for rec in records:
        sigs, fs_, info_, chs = read_wfdb(DATA_DIR, PERSON, rec)
        ecg = sigs[:, 0]
        cor = baseline_correction(ecg, fs_)
        r, _ = find_peaks(cor, height=0.5*np.max(cor), distance=fs_//3)
        if len(r) > 1:
            bpm = 60 / (np.mean(np.diff(r)) / fs_)
            print(f"{rec}: {len(r)} R dalgası, {bpm:.1f} BPM")

#rec_1.hea  → Başlık dosyası (metadata)
#             - Örnekleme frekansı (500 Hz)
 #            - Kanal sayısı
 #            - Yaş, cinsiyet, tarih
  #           - Gain/baseline değerleri

#rec_1.dat  → Asıl sinyal verisi ← EKG sinyali buradan okunuyor!
 #            - Ham sayısal değerler (binary format)
  #           - mV'a dönüştürülerek işleniyor

#rec_1.atr  → Annotation dosyası (şu an kullanılmıyor)
  #           - Uzman tarafından işaretlenmiş R dalgası noktaları
      #       - Karşılaştırma/doğrulama için kullanılabilir
# Out:
# Kayıt okunuyor: Person_07/rec_1
#   Örnekleme Frekansı : 500 Hz
#   Kanal Sayısı       : 2
#   Toplam Örnek       : 10000 (20.0 sn)
#   Yaş         : 21
#   Cinsiyet    : male
#   Tarih       : 15.03.2005
#
# Person_07 için 2 kayıt bulundu: ['rec_1', 'rec_2']
#
# =======================================================
#   İşleniyor: Person_07 / rec_1
# =======================================================
#   Grafik kaydedildi: /kaggle/working/Person_07_rec_1_analiz.png
#   Süre           : 20.0 saniye
#   R Dalgası (ham): 7
#   R Dalgası (cor): 27
#   Kalp Hızı      : 84.0 BPM
#   Ort. RR Aralığı: 714.1 ms
#   RR Std (HRV)   : 162.7 ms
#
# =======================================================
#   İşleniyor: Person_07 / rec_2
# =======================================================
#   Grafik kaydedildi: /kaggle/working/Person_07_rec_2_analiz.png
#   Süre           : 20.0 saniye
#   R Dalgası (ham): 11
#   R Dalgası (cor): 17
#   Kalp Hızı      : 50.7 BPM
#   Ort. RR Aralığı: 1182.9 ms
#   RR Std (HRV)   : 571.2 ms
#
# rec_1: 27 R dalgası, 84.0 BPM
# rec_2: 17 R dalgası, 50.7 BPM
