# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        if filename.endswith('.hea'):
            print(os.path.join(dirname, filename))
            break  # İlk .hea dosyasını bulduktan sonra dur
    else:
        continue
    break
# Out:
# /kaggle/input/datasets/emirhanipek/ekgdata/ecg-id-database-1.0.0/ecg-id-database-1.0.0/Person_07/rec_1.hea
